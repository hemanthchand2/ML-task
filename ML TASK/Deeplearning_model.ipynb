# %%
import numpy as np
import pandas as pd
import math

# %%
# Loading training data
anger_data = pd.read_csv('./datasets/anger_train.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_data = pd.read_csv('./datasets/fear_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_data = pd.read_csv('./datasets/joy_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_data = pd.read_csv('./datasets/sadness_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
anger_data.head()
# Out:
#    index                                              tweet Emotion  score
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger  0.938
# 1  10001  So my Indian Uber driver just called someone t...   anger  0.896
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger  0.896
# 3  10003  so ef whichever butt wipe pulled the fire alar...   anger  0.896
# 4  10004  Don't join @BTCare they put the phone down on ...   anger  0.896

# %%
# Validating data
anger_dev_with_intensity_data = pd.read_csv('./datasets/anger_dev_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_dev_with_intensity_data = pd.read_csv('./datasets/fear_dev_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_dev_with_intensity_data = pd.read_csv('./datasets/joy_dev_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_dev_with_intensity_data = pd.read_csv('./datasets/sadness_dev_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])

anger_dev_data = pd.read_csv('./datasets/anger_dev.txt', sep='\t', names=['tweet', 'Emotion', 'score'])
anger_dev_data.reset_index(drop=False, inplace=True)
anger_dev_data.drop('score', axis=1, inplace=True)

fear_dev_data = pd.read_csv('./datasets/fear_dev.txt', sep='\t', names=['tweet', 'Emotion', 'score'])
fear_dev_data.reset_index(drop=False, inplace=True)
fear_dev_data.drop('score', axis=1, inplace=True)

joy_dev_data = pd.read_csv('./datasets/joy_dev.txt', sep='\t', names=['tweet', 'Emotion', 'score'])
joy_dev_data.reset_index(drop=False, inplace=True)
joy_dev_data.drop('score', axis=1, inplace=True)

sadness_dev_data = pd.read_csv('./datasets/sadness_dev.txt', sep='\t', names=['tweet', 'Emotion', 'score'])
sadness_dev_data.reset_index(drop=False, inplace=True)
sadness_dev_data.drop('score', axis=1, inplace=True)

anger_dev_with_intensity_data.head()
# Out:
#    index                                              tweet Emotion  score
# 0  10941  At the point today where if someone says somet...   anger  0.319
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger  0.144
# 2  10943  This game has pissed me off more than any othe...   anger  0.898
# 3  10944  @spamvicious I've just found out it's Candice ...   anger  0.271
# 4  10945  @moocowward @mrsajhargreaves @Melly77 @GaryBar...   anger  0.646

# %%
anger_dev_data.head()
# Out:
#    index                                              tweet Emotion
# 0  10857  @ZubairSabirPTI  pls dont insult the word 'Molna'   anger
# 1  10858  @ArcticFantasy I would have almost took offens...   anger
# 2  10859  @IllinoisLoyalty that Rutgers game was an abom...   anger
# 3  10860  @CozanGaming that's what lisa asked before she...   anger
# 4  10861  Sometimes I get mad over something so minuscul...   anger

# %%
# Test data
anger_test_with_intensity_data = pd.read_csv('./datasets/anger_test_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_test_with_intensity_data = pd.read_csv('./datasets/fear_test_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_test_with_intensity_data = pd.read_csv('./datasets/joy_test_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_test_with_intensity_data = pd.read_csv('./datasets/sadness_test_w.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])

anger_test_data = pd.read_csv('./datasets/anger_test.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
anger_test_data.drop('score', axis=1, inplace=True)

fear_test_data = pd.read_csv('./datasets/fear_test.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_test_data.drop('score', axis=1, inplace=True)

joy_test_data = pd.read_csv('./datasets/joy_test.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_test_data.drop('score', axis=1, inplace=True)

sadness_test_data = pd.read_csv('./datasets/sadness_test.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_test_data.drop('score', axis=1, inplace=True)

anger_test_with_intensity_data.head()
# Out:
#    index                                              tweet Emotion  score
# 0  10941  At the point today where if someone says somet...   anger  0.319
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger  0.144
# 2  10943  This game has pissed me off more than any othe...   anger  0.898
# 3  10944  @spamvicious I've just found out it's Candice ...   anger  0.271
# 4  10945  @moocowward @mrsajhargreaves @Melly77 @GaryBar...   anger  0.646

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(input_text):
    input_text = re.sub(r'http\S+', '', input_text)
    input_text = re.sub(r'[^\w\s]', '', input_text)
    input_text = input_text.lower()
    tokens = word_tokenize(input_text)
    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]
    return ' '.join(filtered_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\heman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\heman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Applying text preprocessing to training data
anger_train['tweet'] = anger_train['tweet'].apply(preprocess_text)
fear_train['tweet'] = fear_train['tweet'].apply(preprocess_text)
joy_train['tweet'] = joy_train['tweet'].apply(preprocess_text)
sadness_train['tweet'] = sadness_train['tweet'].apply(preprocess_text)

# Applying text preprocessing to development data with intensity
anger_dev_with_intensity['tweet'] = anger_dev_with_intensity['tweet'].apply(preprocess_text)
fear_dev_with_intensity['tweet'] = fear_dev_with_intensity['tweet'].apply(preprocess_text)
joy_dev_with_intensity['tweet'] = joy_dev_with_intensity['tweet'].apply(preprocess_text)
sadness_dev_with_intensity['tweet'] = sadness_dev_with_intensity['tweet'].apply(preprocess_text)

# Applying text preprocessing to development data
anger_dev['tweet'] = anger_dev['tweet'].apply(preprocess_text)
fear_dev['tweet'] = fear_dev['tweet'].apply(preprocess_text)
joy_dev['tweet'] = joy_dev['tweet'].apply(preprocess_text)
sadness_dev['tweet'] = sadness_dev['tweet'].apply(preprocess_text)

# Applying text preprocessing to test data with intensity
anger_test_with_intensity['tweet'] = anger_test_with_intensity['tweet'].apply(preprocess_text)
fear_test_with_intensity['tweet'] = fear_test_with_intensity['tweet'].apply(preprocess_text)
joy_test_with_intensity['tweet'] = joy_test_with_intensity['tweet'].apply(preprocess_text)
sadness_test_with_intensity['tweet'] = sadness_test_with_intensity['tweet'].apply(preprocess_text)

# Applying text preprocessing to test data
anger_test['tweet'] = anger_test['tweet'].apply(preprocess_text)
fear_test['tweet'] = fear_test['tweet'].apply(preprocess_text)
joy_test['tweet'] = joy_test['tweet'].apply(preprocess_text)
sadness_test['tweet'] = sadness_test['tweet'].apply(preprocess_text)

# Example to check the preprocessing on anger_train
anger_train['tweet'][1]
# Out:
# 'indian uber driver called someone n word wasnt moving vehicle id jumped disgusted'

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding, SpatialDropout1D
from keras.callbacks import EarlyStopping

# %%
emotions = ['anger', 'fear', 'joy', 'sadness']
X_train_all = []
y_train_all = []
X_val_all = []
y_val_all = []
X_test_all = []
y_test_all = []

for emotion in emotions:
    X_train = globals()[f"{emotion}_train"]['tweet']
    y_train = globals()[f"{emotion}_train"]['score']
    X_val = globals()[f"{emotion}_dev_with_intensity"]['tweet']
    y_val = globals()[f"{emotion}_dev_with_intensity"]['score']
    X_test = globals()[f"{emotion}_test_with_intensity"]['tweet']
    y_test = globals()[f"{emotion}_test_with_intensity"]['score']

    X_train_all.extend(X_train)
    y_train_all.extend(y_train)
    X_val_all.extend(X_val)
    y_val_all.extend(y_val)
    X_test_all.extend(X_test)
    y_test_all.extend(y_test)

# %%
# Tokenize the text data
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train_all)

X_train_seq = tokenizer.texts_to_sequences(X_train_all)
X_val_seq = tokenizer.texts_to_sequences(X_val_all)
X_test_seq = tokenizer.texts_to_sequences(X_test_all)

# Pad sequences
max_len = max([len(seq) for seq in X_train_seq])
X_train_padded = pad_sequences(X_train_seq, maxlen=max_len, padding='post')
X_val_padded = pad_sequences(X_val_seq, maxlen=max_len, padding='post')
X_test_padded = pad_sequences(X_test_seq, maxlen=max_len, padding='post')

# Convert scores to arrays
y_train_arr = np.array(y_train_all)
y_val_arr = np.array(y_val_all)
y_test_arr = np.array(y_test_all)

# %%
tokenizer.word_index
# Out:
# {'im': 1,
#  'like': 2,
#  'dont': 3,
#  'get': 4,
#  'amp': 5,
#  'one': 6,
#  'people': 7,
#  'time': 8,
#  'day': 9,
#  'know': 10,
#  'good': 11,
#  'love': 12,
#  'u': 13,
#  'cant': 14,
#  'think': 15,
#  'lively': 16,
#  'watch': 17,
#  'still': 18,
#  'would': 19,
#  'got': 20,
#  'go': 21,
#  'make': 22,
#  'today': 23,
#  'happy': 24,
#  'want': 25,
#  'never': 26,
#  'lost': 27,
#  'see': 28,
#  'back': 29,
#  'really': 30,
#  'life': 31,
#  'feel': 32,
#  'always': 33,
#  'need': 34,
#  'way': 35,
#  'amazing': 36,
#  'going': 37,
#  'even': 38,
#  'much': 39,
#  'start': 40,
#  'someone': 41,
#  'work': 42,
#  'right': 43,
#  'na': 44,
#  'sad': 45,
#  'new': 46,
#  'fear': 47,
#  '2': 48,
#  'youre': 49,
#  'ever': 50,
#  'lol': 51,
#  'ive': 52,
#  'anger': 53,
#  'man': 54,
#  'smile': 55,
#  'broadcast': 56,
#  'musically': 57,
#  'us': 58,
#  'first': 59,
#  'angry': 60,
#  'let': 61,
#  'bad': 62,
#  'give': 63,
#  'terrible': 64,
#  'terrorism': 65,
#  'serious': 66,
#  'n': 67,
#  'thats': 68,
#  'best': 69,
#  'great': 70,
#  'fucking': 71,
#  'rage': 72,
#  'something': 73,
#  'didnt': 74,
#  'could': 75,
#  'anxiety': 76,
#  'afraid': 77,
#  'makes': 78,
#  'awful': 79,
#  'bitter': 80,
#  'every': 81,
#  'look': 82,
#  'horror': 83,
#  'next': 84,
#  'better': 85,
#  'stop': 86,
#  'depression': 87,
#  'nightmare': 88,
#  'world': 89,
#  'terror': 90,
#  'well': 91,
#  'say': 92,
#  'optimism': 93,
#  'said': 94,
#  'face': 95,
#  'tonight': 96,
#  'nervous': 97,
#  'last': 98,
#  'panic': 99,
#  'hilarious': 100,
#  'hate': 101,
#  'tell': 102,
#  'ill': 103,
#  '3': 104,
#  'away': 105,
#  'anything': 106,
#  'trump': 107,
#  'thanks': 108,
#  'come': 109,
#  'night': 110,
#  'little': 111,
#  'god': 112,
#  'thing': 113,
#  'getting': 114,
#  'things': 115,
#  'oh': 116,
#  'sadness': 117,
#  'shocking': 118,
#  'find': 119,
#  'doesnt': 120,
#  'worst': 121,
#  'pout': 122,
#  'made': 123,
#  'hope': 124,
#  'week': 125,
#  'dreadful': 126,
#  'offended': 127,
#  'revenge': 128,
#  'team': 129,
#  'black': 130,
#  'take': 131,
#  'gbbo': 132,
#  'long': 133,
#  'unhappy': 134,
#  'despair': 135,
#  'glee': 136,
#  'wan': 137,
#  'old': 138,
#  'maybe': 139,
#  'dark': 140,
#  'horrible': 141,
#  'blues': 142,
#  'another': 143,
#  'shit': 144,
#  'two': 145,
#  'home': 146,
#  'wish': 147,
#  'also': 148,
#  'thought': 149,
#  'laughter': 150,
#  'feeling': 151,
#  'bully': 152,
#  'whole': 153,
#  'guys': 154,
#  'everyone': 155,
#  'wait': 156,
#  'game': 157,
#  'sure': 158,
#  'morning': 159,
#  'sober': 160,
#  'fuming': 161,
#  'use': 162,
#  'help': 163,
#  'end': 164,
#  'days': 165,
#  'thank': 166,
#  'watching': 167,
#  'id': 168,
#  'hes': 169,
#  'everything': 170,
#  'yet': 171,
#  'heart': 172,
#  'lets': 173,
#  'gon': 174,
#  'done': 175,
#  'believe': 176,
#  'year': 177,
#  'play': 178,
#  'quote': 179,
#  'talk': 180,
#  'service': 181,
#  'theres': 182,
#  'person': 183,
#  'twitter': 184,
#  'theyre': 185,
#  'pakistan': 186,
#  'fun': 187,
#  'guy': 188,
#  'hell': 189,
#  'actually': 190,
#  'keep': 191,
#  'anyone': 192,
#  'bit': 193,
#  'frown': 194,
#  'shy': 195,
#  'already': 196,
#  'nothing': 197,
#  'fuck': 198,
#  'snap': 199,
#  'news': 200,
#  'years': 201,
#  'left': 202,
#  'worry': 203,
#  'funny': 204,
#  'excited': 205,
#  'put': 206,
#  'half': 207,
#  'job': 208,
#  'laugh': 209,
#  'looks': 210,
#  'pretty': 211,
#  'live': 212,
#  'tomorrow': 213,
#  'side': 214,
#  'grim': 215,
#  'joyful': 216,
#  'depressing': 217,
#  'phone': 218,
#  'show': 219,
#  'customer': 220,
#  'since': 221,
#  'white': 222,
#  'ur': 223,
#  'needs': 224,
#  'talking': 225,
#  'says': 226,
#  'follow': 227,
#  'alarm': 228,
#  'season': 229,
#  'literally': 230,
#  'leave': 231,
#  'future': 232,
#  'big': 233,
#  'story': 234,
#  'call': 235,
#  'gone': 236,
#  'outrage': 237,
#  'burning': 238,
#  'realdonaldtrump': 239,
#  'many': 240,
#  'fans': 241,
#  'looking': 242,
#  'may': 243,
#  'seen': 244,
#  'try': 245,
#  'used': 246,
#  'shake': 247,
#  'war': 248,
#  'elated': 249,
#  'cheering': 250,
#  'weeks': 251,
#  'furious': 252,
#  'wont': 253,
#  'around': 254,
#  'gets': 255,
#  'turn': 256,
#  'month': 257,
#  'either': 258,
#  'gave': 259,
#  'sorry': 260,
#  'hard': 261,
#  'remember': 262,
#  'please': 263,
#  'awe': 264,
#  'discouraged': 265,
#  'cheer': 266,
#  'bright': 267,
#  'asked': 268,
#  'sometimes': 269,
#  'saying': 270,
#  '4': 271,
#  'part': 272,
#  'madden': 273,
#  'police': 274,
#  'without': 275,
#  'yeah': 276,
#  'though': 277,
#  'real': 278,
#  'must': 279,
#  'isnt': 280,
#  'whats': 281,
#  'trying': 282,
#  'success': 283,
#  'head': 284,
#  'smiling': 285,
#  'stayed': 286,
#  'playful': 287,
#  'pine': 288,
#  'boiling': 289,
#  'raging': 290,
#  'making': 291,
#  'cry': 292,
#  'sick': 293,
#  'order': 294,
#  'house': 295,
#  'mind': 296,
#  'sting': 297,
#  'goes': 298,
#  '1': 299,
#  'fury': 300,
#  'win': 301,
#  'might': 302,
#  'friends': 303,
#  'quite': 304,
#  'least': 305,
#  'care': 306,
#  'ok': 307,
#  'rather': 308,
#  'weary': 309,
#  'playing': 310,
#  'sadly': 311,
#  'change': 312,
#  'country': 313,
#  'cheerful': 314,
#  'pleasing': 315,
#  'animated': 316,
#  'bc': 317,
#  'taking': 318,
#  'woman': 319,
#  'comes': 320,
#  'late': 321,
#  'joke': 322,
#  'support': 323,
#  'free': 324,
#  'eat': 325,
#  'yall': 326,
#  'tears': 327,
#  'offense': 328,
#  'relentless': 329,
#  'ass': 330,
#  'lot': 331,
#  'nice': 332,
#  'sleep': 333,
#  'paul': 334,
#  'started': 335,
#  'delight': 336,
#  'rejoicing': 337,
#  'sparkling': 338,
#  'gloomy': 339,
#  'fire': 340,
#  'tired': 341,
#  'youve': 342,
#  'kind': 343,
#  'damn': 344,
#  'wow': 345,
#  'absolutely': 346,
#  'lmao': 347,
#  'car': 348,
#  'bb18': 349,
#  'class': 350,
#  'times': 351,
#  'players': 352,
#  'burst': 353,
#  'miss': 354,
#  'name': 355,
#  'hillaryclinton': 356,
#  'fact': 357,
#  'wanted': 358,
#  'told': 359,
#  'place': 360,
#  'music': 361,
#  'shaking': 362,
#  '15': 363,
#  'hilarity': 364,
#  'joyous': 365,
#  'rejoice': 366,
#  'exhilarating': 367,
#  'cheery': 368,
#  'hearty': 369,
#  'sunk': 370,
#  'dull': 371,
#  'word': 372,
#  'waiting': 373,
#  'irritate': 374,
#  'yes': 375,
#  'hands': 376,
#  'wonder': 377,
#  'tried': 378,
#  'top': 379,
#  'men': 380,
#  'girl': 381,
#  'run': 382,
#  'offend': 383,
#  'felt': 384,
#  'less': 385,
#  'w': 386,
#  'far': 387,
#  'scare': 388,
#  'fret': 389,
#  'together': 390,
#  'happiness': 391,
#  'havent': 392,
#  'horrific': 393,
#  'restless': 394,
#  'cheerfully': 395,
#  'mourn': 396,
#  'wasnt': 397,
#  'uk': 398,
#  'true': 399,
#  'takes': 400,
#  '10': 401,
#  'human': 402,
#  'room': 403,
#  'self': 404,
#  'lord': 405,
#  'contact': 406,
#  'wrath': 407,
#  'words': 408,
#  'point': 409,
#  'situation': 410,
#  'tv': 411,
#  'water': 412,
#  'finally': 413,
#  'else': 414,
#  'crying': 415,
#  'hey': 416,
#  'guess': 417,
#  'india': 418,
#  'r': 419,
#  'hours': 420,
#  'took': 421,
#  'interview': 422,
#  'kinda': 423,
#  'problem': 424,
#  'episode': 425,
#  'laughing': 426,
#  'video': 427,
#  'couldnt': 428,
#  'family': 429,
#  'concern': 430,
#  'sink': 431,
#  'sweet': 432,
#  'breezy': 433,
#  'chirp': 434,
#  'mad': 435,
#  'called': 436,
#  'happen': 437,
#  'seriously': 438,
#  'saturday': 439,
#  '6': 440,
#  'snapchat': 441,
#  'grudge': 442,
#  'scared': 443,
#  'child': 444,
#  'school': 445,
#  'post': 446,
#  'break': 447,
#  'rabid': 448,
#  'die': 449,
#  'perfect': 450,
#  'boy': 451,
#  'test': 452,
#  'honestly': 453,
#  'truth': 454,
#  'seeing': 455,
#  'texans': 456,
#  'coming': 457,
#  'date': 458,
#  'sense': 459,
#  'terrific': 460,
#  'mean': 461,
#  'hear': 462,
#  'fight': 463,
#  'hold': 464,
#  'rest': 465,
#  'shes': 466,
#  'wrong': 467,
#  'step': 468,
#  'okay': 469,
#  'almost': 470,
#  'wake': 471,
#  'moment': 472,
#  'aint': 473,
#  'gloom': 474,
#  'moving': 475,
#  'pick': 476,
#  'stupid': 477,
#  '5': 478,
#  'cut': 479,
#  'city': 480,
#  'expect': 481,
#  'ones': 482,
#  'haha': 483,
#  'racism': 484,
#  'forgot': 485,
#  'watched': 486,
#  'enough': 487,
#  'kid': 488,
#  'cause': 489,
#  'fan': 490,
#  'youtube': 491,
#  'dog': 492,
#  'hurt': 493,
#  'within': 494,
#  'america': 495,
#  'high': 496,
#  'act': 497,
#  'found': 498,
#  'soon': 499,
#  'yesterday': 500,
#  'played': 501,
#  'lies': 502,
#  'truly': 503,
#  'full': 504,
#  'attack': 505,
#  'dream': 506,
#  'book': 507,
#  '20': 508,
#  'movie': 509,
#  'vote': 510,
#  'rojo': 511,
#  'horrid': 512,
#  'outside': 513,
#  'experience': 514,
#  'beautiful': 515,
#  'birthday': 516,
#  'accept': 517,
#  'indian': 518,
#  'sound': 519,
#  'money': 520,
#  'blood': 521,
#  'wtf': 522,
#  'power': 523,
#  'working': 524,
#  'fiery': 525,
#  'insult': 526,
#  'second': 527,
#  'straight': 528,
#  'blame': 529,
#  'kids': 530,
#  'happened': 531,
#  'poor': 532,
#  'supposed': 533,
#  'social': 534,
#  'charlotte': 535,
#  'hour': 536,
#  'internet': 537,
#  'positive': 538,
#  'ready': 539,
#  'media': 540,
#  'hair': 541,
#  'fail': 542,
#  'hungry': 543,
#  'hillary': 544,
#  'church': 545,
#  'v': 546,
#  'forward': 547,
#  'others': 548,
#  'ta': 549,
#  'feels': 550,
#  'lots': 551,
#  'plus': 552,
#  'wouldnt': 553,
#  'drop': 554,
#  'alone': 555,
#  'seems': 556,
#  'broken': 557,
#  'etc': 558,
#  'hand': 559,
#  'short': 560,
#  'joy': 561,
#  'running': 562,
#  'peace': 563,
#  'b': 564,
#  'went': 565,
#  'song': 566,
#  'omg': 567,
#  'race': 568,
#  'dread': 569,
#  'levity': 570,
#  'heyday': 571,
#  'understand': 572,
#  'road': 573,
#  'taken': 574,
#  'minutes': 575,
#  'party': 576,
#  'ago': 577,
#  'kill': 578,
#  'online': 579,
#  '2016': 580,
#  'fighting': 581,
#  'jesus': 582,
#  'king': 583,
#  'forever': 584,
#  'food': 585,
#  'walk': 586,
#  'nap': 587,
#  'letting': 588,
#  'surprised': 589,
#  'resent': 590,
#  'justice': 591,
#  'gun': 592,
#  'forget': 593,
#  'looting': 594,
#  'women': 595,
#  'cops': 596,
#  'dear': 597,
#  'knows': 598,
#  'thinking': 599,
#  'cool': 600,
#  'attacks': 601,
#  'bed': 602,
#  'tweet': 603,
#  'dad': 604,
#  'bring': 605,
#  'young': 606,
#  'heard': 607,
#  'wants': 608,
#  'loves': 609,
#  'beat': 610,
#  'buy': 611,
#  'hot': 612,
#  'chris': 613,
#  'starts': 614,
#  'vs': 615,
#  'grow': 616,
#  'important': 617,
#  'fall': 618,
#  'stay': 619,
#  'mhchat': 620,
#  'starting': 621,
#  'discourage': 622,
#  'evening': 623,
#  'state': 624,
#  'lady': 625,
#  'glad': 626,
#  'confused': 627,
#  'depress': 628,
#  'pessimist': 629,
#  'using': 630,
#  'soul': 631,
#  'shut': 632,
#  'fine': 633,
#  'card': 634,
#  'received': 635,
#  'stuff': 636,
#  'ya': 637,
#  'smh': 638,
#  'paid': 639,
#  'absolute': 640,
#  'provoke': 641,
#  'hit': 642,
#  'changing': 643,
#  'stuck': 644,
#  'form': 645,
#  'early': 646,
#  'living': 647,
#  'express': 648,
#  'air': 649,
#  'issues': 650,
#  'listen': 651,
#  'sex': 652,
#  'happens': 653,
#  'across': 654,
#  '8': 655,
#  'worse': 656,
#  'round': 657,
#  'sister': 658,
#  'leaves': 659,
#  'instead': 660,
#  'itll': 661,
#  'imagine': 662,
#  'eating': 663,
#  'train': 664,
#  '12': 665,
#  'mood': 666,
#  'british': 667,
#  'close': 668,
#  'john': 669,
#  'sit': 670,
#  'arms': 671,
#  'lovely': 672,
#  'shouldnt': 673,
#  'sat': 674,
#  'youll': 675,
#  'past': 676,
#  'lose': 677,
#  'goals': 678,
#  'behind': 679,
#  'super': 680,
#  '7': 681,
#  'speech': 682,
#  'friday': 683,
#  'trust': 684,
#  'dismal': 685,
#  'met': 686,
#  'pitch': 687,
#  'coffee': 688,
#  'hesitate': 689,
#  'saw': 690,
#  'action': 691,
#  'wonderful': 692,
#  'gleeful': 693,
#  'x': 694,
#  'jovial': 695,
#  'exhilaration': 696,
#  'sulk': 697,
#  'delivered': 698,
#  'dude': 699,
#  'biggest': 700,
#  'ppl': 701,
#  'front': 702,
#  'bitch': 703,
#  'later': 704,
#  'means': 705,
#  'bloody': 706,
#  'bill': 707,
#  'different': 708,
#  'fair': 709,
#  'tantrums': 710,
#  'months': 711,
#  'brother': 712,
#  'reply': 713,
#  'manutd': 714,
#  'goal': 715,
#  'clown': 716,
#  'american': 717,
#  'protest': 718,
#  'whos': 719,
#  'friend': 720,
#  'ugh': 721,
#  'ball': 722,
#  'become': 723,
#  'football': 724,
#  'idea': 725,
#  'americans': 726,
#  'respect': 727,
#  'towards': 728,
#  'radio': 729,
#  'history': 730,
#  'girls': 731,
#  '100': 732,
#  'character': 733,
#  'draw': 734,
#  'conversation': 735,
#  'rip': 736,
#  'came': 737,
#  'brown': 738,
#  'tho': 739,
#  'cross': 740,
#  'body': 741,
#  'beyond': 742,
#  'gt': 743,
#  'posted': 744,
#  'turns': 745,
#  'leads': 746,
#  'writing': 747,
#  'listening': 748,
#  'often': 749,
#  'move': 750,
#  'series': 751,
#  'extra': 752,
#  'clear': 753,
#  'strong': 754,
#  'cuz': 755,
#  'wwe': 756,
#  'grateful': 757,
#  'rooney': 758,
#  'thoughts': 759,
#  'singing': 760,
#  'ran': 761,
#  'read': 762,
#  'balls': 763,
#  'course': 764,
#  'nails': 765,
#  'assume': 766,
#  'save': 767,
#  'awareness': 768,
#  'business': 769,
#  'single': 770,
#  'mark': 771,
#  'death': 772,
#  'scary': 773,
#  'doom': 774,
#  'dumb': 775,
#  'along': 776,
#  'wednesday': 777,
#  'simply': 778,
#  'dire': 779,
#  'greatest': 780,
#  'normal': 781,
#  'punch': 782,
#  'campaign': 783,
#  'penny': 784,
#  'check': 785,
#  'cover': 786,
#  'film': 787,
#  'ask': 788,
#  'challenges': 789,
#  'grieve': 790,
#  'pissed': 791,
#  'weve': 792,
#  'ages': 793,
#  'mention': 794,
#  'ticket': 795,
#  'turned': 796,
#  'update': 797,
#  'iphone': 798,
#  'nearly': 799,
#  'bet': 800,
#  'killed': 801,
#  'coach': 802,
#  'blacks': 803,
#  'carpet': 804,
#  'em': 805,
#  'candice': 806,
#  'wind': 807,
#  'process': 808,
#  'sun': 809,
#  'sitting': 810,
#  'floor': 811,
#  'longer': 812,
#  'easily': 813,
#  'usa': 814,
#  'baby': 815,
#  'inner': 816,
#  'children': 817,
#  'hello': 818,
#  'trash': 819,
#  'foot': 820,
#  'mate': 821,
#  'father': 822,
#  'obviously': 823,
#  'reading': 824,
#  'decision': 825,
#  'match': 826,
#  'deal': 827,
#  'red': 828,
#  'ep': 829,
#  'ex': 830,
#  'drunk': 831,
#  'videos': 832,
#  'election': 833,
#  'holding': 834,
#  'ugly': 835,
#  'whether': 836,
#  'incense': 837,
#  'knew': 838,
#  'worth': 839,
#  'simple': 840,
#  'study': 841,
#  'eyes': 842,
#  'anyway': 843,
#  'problems': 844,
#  'gods': 845,
#  'level': 846,
#  'favorite': 847,
#  'line': 848,
#  'lives': 849,
#  'complete': 850,
#  'realize': 851,
#  'bday': 852,
#  'awesome': 853,
#  'fearing': 854,
#  'set': 855,
#  'alive': 856,
#  'feet': 857,
#  'promise': 858,
#  'cup': 859,
#  'weekend': 860,
#  'jk': 861,
#  'easy': 862,
#  'nights': 863,
#  'frightened': 864,
#  'project': 865,
#  'college': 866,
#  'parents': 867,
#  'calm': 868,
#  'terrorist': 869,
#  'mufc': 870,
#  'shows': 871,
#  'stand': 872,
#  'office': 873,
#  'unga': 874,
#  'stopped': 875,
#  'exist': 876,
#  'issue': 877,
#  'courage': 878,
#  'recent': 879,
#  'company': 880,
#  'threaten': 881,
#  'pak': 882,
#  'arent': 883,
#  'leadership': 884,
#  'training': 885,
#  'intimidate': 886,
#  'mother': 887,
#  'research': 888,
#  'tells': 889,
#  'lack': 890,
#  'haunt': 891,
#  'val': 892,
#  'policy': 893,
#  'light': 894,
#  'bro': 895,
#  'faith': 896,
#  'final': 897,
#  'filled': 898,
#  'dry': 899,
#  'blessed': 900,
#  'mirth': 901,
#  'jubilant': 902,
#  'health': 903,
#  'cheerfulness': 904,
#  'frowning': 905,
#  'door': 906,
#  'disgusted': 907,
#  'store': 908,
#  'upset': 909,
#  'hangry': 910,
#  'rude': 911,
#  'known': 912,
#  'appearance': 913,
#  'zero': 914,
#  'photo': 915,
#  'block': 916,
#  'everywhere': 917,
#  'quit': 918,
#  'response': 919,
#  'inside': 920,
#  'ladies': 921,
#  'machines': 922,
#  'reason': 923,
#  'comments': 924,
#  'ordered': 925,
#  'hasnt': 926,
#  'cantsleep': 927,
#  'mom': 928,
#  'calling': 929,
#  'ms': 930,
#  'dying': 931,
#  'e': 932,
#  'mistake': 933,
#  'michelle': 934,
#  'ha': 935,
#  'huff': 936,
#  'swear': 937,
#  'due': 938,
#  'add': 939,
#  'record': 940,
#  'shot': 941,
#  'destroy': 942,
#  'charlotteprotest': 943,
#  'definitely': 944,
#  'broke': 945,
#  'apparently': 946,
#  'negative': 947,
#  'control': 948,
#  'dick': 949,
#  'giving': 950,
#  'ruffle': 951,
#  'emoji': 952,
#  'based': 953,
#  'vacation': 954,
#  'shooting': 955,
#  'anniversary': 956,
#  'allow': 957,
#  'behavior': 958,
#  'case': 959,
#  'describe': 960,
#  'somewhere': 961,
#  'soft': 962,
#  'everybody': 963,
#  'ways': 964,
#  'pure': 965,
#  'probably': 966,
#  'crap': 967,
#  'blue': 968,
#  'summer': 969,
#  'yo': 970,
#  'midnight': 971,
#  'account': 972,
#  'cats': 973,
#  'enjoy': 974,
#  'despite': 975,
#  'comedy': 976,
#  'held': 977,
#  'tulsa': 978,
#  'movies': 979,
#  'names': 980,
#  'bored': 981,
#  'worried': 982,
#  'learn': 983,
#  'obama': 984,
#  'speak': 985,
#  'continue': 986,
#  'exactly': 987,
#  'drink': 988,
#  't': 989,
#  'challenge': 990,
#  'bus': 991,
#  'group': 992,
#  'tiff': 993,
#  'jimmy': 994,
#  'seem': 995,
#  'facts': 996,
#  'drive': 997,
#  'player': 998,
#  'victory': 999,
#  'network': 1000,
#  ...}

# %%
max_len
# Out:
# 19

# %%
X_train_padded.shape
# Out:
# (3613, 19)

# %%
X_val_padded.shape
# Out:
# (1908, 19)

# %%
y_train_arr.shape
# Out:
# (3613,)

# %%
y_val_arr.shape
# Out:
# (1908,)

# %%
# Define the model
emotion_model = Sequential()
emotion_model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_shape=[max_len]))
emotion_model.add(SpatialDropout1D(0.2))
emotion_model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
emotion_model.add(Dense(1, activation='linear'))

# Compile the model
emotion_model.compile(loss='mean_squared_error', optimizer='adam')

# Print model summary
emotion_model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)              │ (None, 19, 100)             │       1,042,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout1d_3                  │ (None, 19, 100)             │               0 │
# │ (SpatialDropout1D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 100)                 │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,123,301 (4.29 MB)
#  Trainable params: 1,123,301 (4.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train_padded, y_train_arr, epochs=10, batch_size=32, validation_data=(X_val_padded, y_val_arr))
# Out:
# Epoch 1/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0672 - val_loss: 0.0360
# Epoch 2/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0360 - val_loss: 0.0315
# Epoch 3/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0246 - val_loss: 0.0284
# Epoch 4/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0183 - val_loss: 0.0288
# Epoch 5/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0146 - val_loss: 0.0287
# Epoch 6/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0128 - val_loss: 0.0289
# Epoch 7/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0113 - val_loss: 0.0313
# Epoch 8/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0106 - val_loss: 0.0315
# Epoch 9/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0093 - val_loss: 0.0317
# Epoch 10/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0090 - val_loss: 0.0330

# %%
val_loss = model.evaluate(X_val_padded, y_val_arr)
print(f"Validation Loss: {val_loss}")
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0318
# Validation Loss: 0.0329941026866436

# %%
result = model.evaluate(X_test_padded, y_test_arr)
print(f"Test Loss: {result}")
# Out:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0337
# Test Loss: 0.036644790321588516
